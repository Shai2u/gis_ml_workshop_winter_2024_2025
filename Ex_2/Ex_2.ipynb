# %% [markdown]
# ![Image Description](../images/course_logo_2025.png)

# %% [markdown]
# # Ex 2: Data Wrangling, Cleaning and Enhancing

# %% [markdown]
# ![Image Description](../images/ds_cycle.png)

# %% [markdown]
# # Data Source

# %% [markdown]
# [Real Estate New York](https://www.kaggle.com/datasets/manishpatil009/real-estate-in-new-york?resource=download)
#
# This is a dataset about the properties in New York City.
# The data was **scraped** from Trulia Website with the help of selenium Webdriver. This dataset contains the Name of the property, the city where the property belongs, the Neighborhood, the Price of the Property in USD, the year the property was built in, the beds, baths , Area per Square Feet and the status Air Conditioning. **No Geographic Coordinates.**

# %% [markdown]
# [MapPluto](https://www.nyc.gov/site/planning/data-maps/open-data/dwn-pluto-mappluto.page)
#
# Extensive land use and geographic data at the tax lot level in comma-separated values (CSV) file format. The PLUTO files contain more than seventy fields derived from data maintained by city agencies. **Used for Geographic reference**
# ![Image Description](../images/MapPluto_lots.png)

# %%
# Loading the libraries
from fuzzywuzzy import process
import geopandas as gpd
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from tqdm import tqdm

# %%
# Loading Real Estate data
real_estate_df = pd.read_csv('https://raw.githubusercontent.com/Shai2u/gis_ml_workshop_winter_2024_2025/refs/heads/Ex_2/Ex_2/real_estate_nyc.csv')

# %%
real_estate_df.head()
# Out:
#    Unnamed: 0                    Name                        City  \
# 0           0  3324 Junction Blvd #5X   Jackson Heights, NY 11372
# 1           1       37-26 32nd St #5K  Long Island City, NY 11101
# 2           2       37-26 32nd St #3G  Long Island City, NY 11101
# 3           3       37-26 32nd St #6L  Long Island City, NY 11101
# 4           4       37-26 32nd St #3H  Long Island City, NY 11101
#
#      Neighbourhood     Price        Year Built    Beds   Baths      Area  \
# 0  Jackson Heights  $285,000              Null   1 Bed  1 Bath  800 sqft
# 1          Astoria  $620,000  Year Built: 2022  Studio  1 Bath  441 sqft
# 2          Astoria  $730,000  Year Built: 2022   1 Bed  1 Bath  579 sqft
# 3          Astoria  $570,000  Year Built: 2022  Studio  1 Bath  429 sqft
# 4          Astoria  $695,000  Year Built: 2022   1 Bed  1 Bath  632 sqft
#
#   Price(per sqft)           A/C
# 0            $356  Cooling only
# 1          $1,406  Cooling only
# 2          $1,261  Cooling only
# 3          $1,329  Cooling only
# 4          $1,100            No

# %%
# Remove Unnamed: 0
real_estate_df = pd.read_csv('https://raw.githubusercontent.com/Shai2u/gis_ml_workshop_winter_2024_2025/refs/heads/Ex_2/Ex_2/real_estate_nyc.csv', index_col=0)

# %%
real_estate_df.head()
# Out:
#                      Name                        City    Neighbourhood  \
# 0  3324 Junction Blvd #5X   Jackson Heights, NY 11372  Jackson Heights
# 1       37-26 32nd St #5K  Long Island City, NY 11101          Astoria
# 2       37-26 32nd St #3G  Long Island City, NY 11101          Astoria
# 3       37-26 32nd St #6L  Long Island City, NY 11101          Astoria
# 4       37-26 32nd St #3H  Long Island City, NY 11101          Astoria
#
#       Price        Year Built    Beds   Baths      Area Price(per sqft)  \
# 0  $285,000              Null   1 Bed  1 Bath  800 sqft            $356
# 1  $620,000  Year Built: 2022  Studio  1 Bath  441 sqft          $1,406
# 2  $730,000  Year Built: 2022   1 Bed  1 Bath  579 sqft          $1,261
# 3  $570,000  Year Built: 2022  Studio  1 Bath  429 sqft          $1,329
# 4  $695,000  Year Built: 2022   1 Bed  1 Bath  632 sqft          $1,100
#
#             A/C
# 0  Cooling only
# 1  Cooling only
# 2  Cooling only
# 3  Cooling only
# 4            No

# %%
real_estate_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 387 entries, 0 to 386
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             387 non-null    object
#  1   City             387 non-null    object
#  2   Neighbourhood    387 non-null    object
#  3   Price            387 non-null    object
#  4   Year Built       387 non-null    object
#  5   Beds             387 non-null    object
#  6   Baths            387 non-null    object
#  7   Area             387 non-null    object
#  8   Price(per sqft)  387 non-null    object
#  9   A/C              387 non-null    object
# dtypes: object(10)
# memory usage: 33.3+ KB

# %% [markdown]
# # 🧐

# %%
real_estate_df['Name'].value_counts()
# Out:
# Name
# 3324 Junction Blvd #5X            10
# 117 E 57th St #41F                10
# 150 E 69th St #3M                 10
# 2415 E 64th St                    10
# 410 Maryland Ave #1C              10
# 140 E 2nd St #6U                  10
# 195 Classon Ave #5                10
# 43 Joralemon St                   10
# 37-26 32nd St #5K                 10
# 1619 3rd Ave #3B                  10
# 99-12 199th Street                10
# 6243 79th St                      10
# 661 Amsterdam Ave #5E             10
# 433 Monroe St                     10
# 2339 Matthews Ave #W              10
# 97-40 62nd Dr #8F                 10
# 2736 Independence Ave #6J         10
# 137-08 31st Rd #2                 10
# 37-26 32nd St #3G                 10
# 37-26 32nd St #6L                 10
# 4 E 88th St #5C                   10
# 37-26 32nd St #3H                 10
# 216-02 67th Ave #D                10
# 450 Jersey St                     10
# 1518 Canarsie Rd                  10
# 77-14 113th Street UNIT 3C        10
# 86-19 115th Street                10
# 398 Kings Hwy #203                 9
# 11 Quinn St                        9
# 1247 E 86th Street                 9
# 35-42 77th St #22                  9
# 3112 Mickle Avenue                 9
# 377 Rector Pl #11A                 9
# 321 E 43rd St #515                 9
# 580 Carroll St #4C                 9
# 43-55 Kissena Blvd UNIT 3B         9
# 180-16 Wexford Terrace UNIT 2F     9
# 3656 Johnson Ave #2G               9
# 150-23 Hoover Avenue               9
# 22 Windham Loop #1A                9
# Name: count, dtype: int64

# %%
len(real_estate_df)
# Out:
# 387

# %%
len(real_estate_df.drop_duplicates())
# Out:
# 41

# %%
real_estate_df = real_estate_df.drop_duplicates().reset_index(drop=True)

# %%
len(real_estate_df)
# Out:
# 41

# %%
real_estate_df['Name'].value_counts()
# Out:
# Name
# 150 E 69th St #3M                 2
# 3324 Junction Blvd #5X            1
# 37-26 32nd St #5K                 1
# 195 Classon Ave #5                1
# 140 E 2nd St #6U                  1
# 410 Maryland Ave #1C              1
# 2415 E 64th St                    1
# 321 E 43rd St #515                1
# 150-23 Hoover Avenue              1
# 3656 Johnson Ave #2G              1
# 180-16 Wexford Terrace UNIT 2F    1
# 43-55 Kissena Blvd UNIT 3B        1
# 580 Carroll St #4C                1
# 398 Kings Hwy #203                1
# 377 Rector Pl #11A                1
# 3112 Mickle Avenue                1
# 35-42 77th St #22                 1
# 1247 E 86th Street                1
# 11 Quinn St                       1
# 43 Joralemon St                   1
# 2339 Matthews Ave #W              1
# 1619 3rd Ave #3B                  1
# 1518 Canarsie Rd                  1
# 37-26 32nd St #3G                 1
# 37-26 32nd St #6L                 1
# 37-26 32nd St #3H                 1
# 4 E 88th St #5C                   1
# 2736 Independence Ave #6J         1
# 216-02 67th Ave #D                1
# 450 Jersey St                     1
# 77-14 113th Street UNIT 3C        1
# 99-12 199th Street                1
# 86-19 115th Street                1
# 137-08 31st Rd #2                 1
# 97-40 62nd Dr #8F                 1
# 117 E 57th St #41F                1
# 433 Monroe St                     1
# 661 Amsterdam Ave #5E             1
# 6243 79th St                      1
# 22 Windham Loop #1A               1
# Name: count, dtype: int64

# %%
real_estate_df.head()
# Out:
#                      Name                        City    Neighbourhood  \
# 0  3324 Junction Blvd #5X   Jackson Heights, NY 11372  Jackson Heights
# 1       37-26 32nd St #5K  Long Island City, NY 11101          Astoria
# 2       37-26 32nd St #3G  Long Island City, NY 11101          Astoria
# 3       37-26 32nd St #6L  Long Island City, NY 11101          Astoria
# 4       37-26 32nd St #3H  Long Island City, NY 11101          Astoria
#
#       Price        Year Built    Beds   Baths      Area Price(per sqft)  \
# 0  $285,000              Null   1 Bed  1 Bath  800 sqft            $356
# 1  $620,000  Year Built: 2022  Studio  1 Bath  441 sqft          $1,406
# 2  $730,000  Year Built: 2022   1 Bed  1 Bath  579 sqft          $1,261
# 3  $570,000  Year Built: 2022  Studio  1 Bath  429 sqft          $1,329
# 4  $695,000  Year Built: 2022   1 Bed  1 Bath  632 sqft          $1,100
#
#             A/C
# 0  Cooling only
# 1  Cooling only
# 2  Cooling only
# 3  Cooling only
# 4            No

# %%
real_estate_df['Address'] = real_estate_df['Name'].str.split('#').str[0]
real_estate_df['Apartment'] = real_estate_df['Name'].str.split('#').str[1]

# %%
real_estate_df.head()
# Out:
#                      Name                        City    Neighbourhood  \
# 0  3324 Junction Blvd #5X   Jackson Heights, NY 11372  Jackson Heights
# 1       37-26 32nd St #5K  Long Island City, NY 11101          Astoria
# 2       37-26 32nd St #3G  Long Island City, NY 11101          Astoria
# 3       37-26 32nd St #6L  Long Island City, NY 11101          Astoria
# 4       37-26 32nd St #3H  Long Island City, NY 11101          Astoria
#
#       Price        Year Built    Beds   Baths      Area Price(per sqft)  \
# 0  $285,000              Null   1 Bed  1 Bath  800 sqft            $356
# 1  $620,000  Year Built: 2022  Studio  1 Bath  441 sqft          $1,406
# 2  $730,000  Year Built: 2022   1 Bed  1 Bath  579 sqft          $1,261
# 3  $570,000  Year Built: 2022  Studio  1 Bath  429 sqft          $1,329
# 4  $695,000  Year Built: 2022   1 Bed  1 Bath  632 sqft          $1,100
#
#             A/C              Address Apartment
# 0  Cooling only  3324 Junction Blvd         5X
# 1  Cooling only       37-26 32nd St         5K
# 2  Cooling only       37-26 32nd St         3G
# 3  Cooling only       37-26 32nd St         6L
# 4            No       37-26 32nd St         3H

# %%
real_estate_df['City'].value_counts()
# Out:
# City
# Long Island City, NY 11101    4
# Jackson Heights, NY 11372     2
# Jamaica, NY 11432             2
# New York, NY 10128            2
# Bronx, NY 10463               2
# Brooklyn, NY 11236            2
# New York, NY 10065            2
# Staten Island, NY 10305       1
# Brooklyn, NY 11234            1
# New York, NY 10017            1
# Brooklyn, NY 11215            1
# Flushing, NY 11355            1
# Brooklyn, NY 11205            1
# Brooklyn, NY 11223            1
# New York, NY 10280            1
# Bronx, NY 10469               1
# Staten Island, NY 10304       1
# Brooklyn, NY 11218            1
# Bronx, NY 10467               1
# Brooklyn, NY 11201            1
# Hollis, NY 11423              1
# Flushing, NY 11379            1
# New York, NY 10025            1
# Brooklyn, NY 11221            1
# New York, NY 10022            1
# Rego Park, NY 11374           1
# Flushing, NY 11354            1
# Richmond Hill, NY 11418       1
# Forest Hills, NY 11375        1
# Staten Island, NY 10301       1
# Oakland Gardens, NY 11364     1
# Staten Island, NY 10314       1
# Name: count, dtype: int64

# %%
real_estate_df['City_short'] = real_estate_df['City'].str.split(', NY ').str[0]

# %%
real_estate_df['postal_code'] = real_estate_df['City'].str.split(', NY ').str[1].astype(int)

# %%
real_estate_df['state']  = 'NY'

# %%
real_estate_df['City_short'].value_counts()
# Out:
# City_short
# Brooklyn            9
# New York            8
# Long Island City    4
# Bronx               4
# Staten Island       4
# Flushing            3
# Jackson Heights     2
# Jamaica             2
# Oakland Gardens     1
# Forest Hills        1
# Richmond Hill       1
# Rego Park           1
# Hollis              1
# Name: count, dtype: int64

# %%
real_estate_df.drop(columns=['City'], inplace=True)

# %%
real_estate_df.head()
# Out:
#                      Name    Neighbourhood     Price        Year Built  \
# 0  3324 Junction Blvd #5X  Jackson Heights  $285,000              Null
# 1       37-26 32nd St #5K          Astoria  $620,000  Year Built: 2022
# 2       37-26 32nd St #3G          Astoria  $730,000  Year Built: 2022
# 3       37-26 32nd St #6L          Astoria  $570,000  Year Built: 2022
# 4       37-26 32nd St #3H          Astoria  $695,000  Year Built: 2022
#
#      Beds   Baths      Area Price(per sqft)           A/C  \
# 0   1 Bed  1 Bath  800 sqft            $356  Cooling only
# 1  Studio  1 Bath  441 sqft          $1,406  Cooling only
# 2   1 Bed  1 Bath  579 sqft          $1,261  Cooling only
# 3  Studio  1 Bath  429 sqft          $1,329  Cooling only
# 4   1 Bed  1 Bath  632 sqft          $1,100            No
#
#                Address Apartment        City_short  postal_code state
# 0  3324 Junction Blvd         5X   Jackson Heights        11372    NY
# 1       37-26 32nd St         5K  Long Island City        11101    NY
# 2       37-26 32nd St         3G  Long Island City        11101    NY
# 3       37-26 32nd St         6L  Long Island City        11101    NY
# 4       37-26 32nd St         3H  Long Island City        11101    NY

# %%
real_estate_df['Neighbourhood'].value_counts()
# Out:
# Neighbourhood
# Astoria               4
# Upper East Side       3
# Canarsie              2
# Bedford Stuyvesant    2
# Flushing              2
# Jackson Heights       2
# New Brighton          1
# Forest Hills          1
# Stapleton             1
# Baychester            1
# Battery Park          1
# Gravesend             1
# Park Slope            1
# Jamaica Estates       1
# Riverdale             1
# Briarwood             1
# Turtle Bay            1
# Mill Basin            1
# Rosebank              1
# Windsor Terrace       1
# Brooklyn Heights      1
# Williamsbridge        1
# Carnegie Hill         1
# Hollis                1
# Middle Village        1
# Upper West Side       1
# Spuyten Duyvil        1
# Midtown               1
# Rego Park             1
# Oakland Gardens       1
# Richmond Hill         1
# Heartland Village     1
# Name: count, dtype: int64

# %%
real_estate_df.head()
# Out:
#                      Name    Neighbourhood     Price        Year Built  \
# 0  3324 Junction Blvd #5X  Jackson Heights  $285,000              Null
# 1       37-26 32nd St #5K          Astoria  $620,000  Year Built: 2022
# 2       37-26 32nd St #3G          Astoria  $730,000  Year Built: 2022
# 3       37-26 32nd St #6L          Astoria  $570,000  Year Built: 2022
# 4       37-26 32nd St #3H          Astoria  $695,000  Year Built: 2022
#
#      Beds   Baths      Area Price(per sqft)           A/C  \
# 0   1 Bed  1 Bath  800 sqft            $356  Cooling only
# 1  Studio  1 Bath  441 sqft          $1,406  Cooling only
# 2   1 Bed  1 Bath  579 sqft          $1,261  Cooling only
# 3  Studio  1 Bath  429 sqft          $1,329  Cooling only
# 4   1 Bed  1 Bath  632 sqft          $1,100            No
#
#                Address Apartment        City_short  postal_code state
# 0  3324 Junction Blvd         5X   Jackson Heights        11372    NY
# 1       37-26 32nd St         5K  Long Island City        11101    NY
# 2       37-26 32nd St         3G  Long Island City        11101    NY
# 3       37-26 32nd St         6L  Long Island City        11101    NY
# 4       37-26 32nd St         3H  Long Island City        11101    NY

# %%
real_estate_df['Price_'] = real_estate_df['Price'].str.replace('$', '').str.replace(',', '').astype(int)

# %%
sns.histplot(real_estate_df['Price_'], bins=25)
# Out:
# <Axes: xlabel='Price_', ylabel='Count'>

# %%
sns.boxplot(y='Price_', data=real_estate_df)
# Out:
# <Axes: ylabel='Price_'>

# %%
real_estate_df['Price_'].describe()
# Out:
# count    4.100000e+01
# mean     8.856850e+05
# std      7.452819e+05
# min      1.790000e+05
# 25%      4.500000e+05
# 50%      6.950000e+05
# 75%      9.999000e+05
# max      4.500000e+06
# Name: Price_, dtype: float64

# %%
real_estate_df.drop(columns=['Price'], inplace=True)

# %%
real_estate_df['Year Built'].value_counts()
# Out:
# Year Built
# Year Built: 2022    5
# Year Built: 1940    3
# Year Built: 1975    3
# Null                2
# Year Built: 1959    2
# Year Built: 1950    2
# Year Built: 1899    2
# Year Built: 1955    2
# Year Built: 1938    2
# Year Built: 1920    2
# Year Built: 1986    1
# Year Built: 2009    1
# Year Built: 1985    1
# Year Built: 1921    1
# Year Built: 1932    1
# Year Built: 1945    1
# Year Built: 1928    1
# Year Built: 1845    1
# Year Built: 1965    1
# Year Built: 1974    1
# Year Built: 2008    1
# Year Built: 2007    1
# Year Built: 1910    1
# Year Built: 1970    1
# Year Built: 1922    1
# Year Built: 1915    1
# Name: count, dtype: int64

# %%
sum(real_estate_df['Year Built'] == 'Null')
# Out:
# 2

# %%
real_estate_df['Year Built int'] = real_estate_df['Year Built'].str.split('Year Built:').str[1].astype(float)

# %%
real_estate_df.head()
# Out:
#                      Name    Neighbourhood        Year Built    Beds   Baths  \
# 0  3324 Junction Blvd #5X  Jackson Heights              Null   1 Bed  1 Bath
# 1       37-26 32nd St #5K          Astoria  Year Built: 2022  Studio  1 Bath
# 2       37-26 32nd St #3G          Astoria  Year Built: 2022   1 Bed  1 Bath
# 3       37-26 32nd St #6L          Astoria  Year Built: 2022  Studio  1 Bath
# 4       37-26 32nd St #3H          Astoria  Year Built: 2022   1 Bed  1 Bath
#
#        Area Price(per sqft)           A/C              Address Apartment  \
# 0  800 sqft            $356  Cooling only  3324 Junction Blvd         5X
# 1  441 sqft          $1,406  Cooling only       37-26 32nd St         5K
# 2  579 sqft          $1,261  Cooling only       37-26 32nd St         3G
# 3  429 sqft          $1,329  Cooling only       37-26 32nd St         6L
# 4  632 sqft          $1,100            No       37-26 32nd St         3H
#
#          City_short  postal_code state  Price_  Year Built int
# 0   Jackson Heights        11372    NY  285000             NaN
# 1  Long Island City        11101    NY  620000          2022.0
# 2  Long Island City        11101    NY  730000          2022.0
# 3  Long Island City        11101    NY  570000          2022.0
# 4  Long Island City        11101    NY  695000          2022.0

# %%
real_estate_df['Year Built int'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# Cell In[178], line 1
# ----> 1 real_estate_df['Year Built int'].astype(int)
#
# File ~/anaconda3/envs/ds_conda_venv/lib/python3.10/site-packages/pandas/core/generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
#    6642     # else, only a single dtype is given
# -> 6643     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645     return res.__finalize__(self, method="astype")
#
# File ~/anaconda3/envs/ds_conda_venv/lib/python3.10/site-packages/pandas/core/internals/managers.py:430, in BaseBlockManager.astype(self, dtype, copy, errors)
#     427 elif using_copy_on_write():
#     428     copy = False
# --> 430 return self.apply(
#     431     "astype",
#     432     dtype=dtype,
#     433     copy=copy,
#     434     errors=errors,
#     435     using_cow=using_copy_on_write(),
#     436 )
#
# File ~/anaconda3/envs/ds_conda_venv/lib/python3.10/site-packages/pandas/core/internals/managers.py:363, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     361         applied = b.apply(f, **kwargs)
#     362     else:
# --> 363         applied = getattr(b, f)(**kwargs)
#     364     result_blocks = extend_blocks(applied, result_blocks)
#     366 out = type(self).from_blocks(result_blocks, self.axes)
#
# File ~/anaconda3/envs/ds_conda_venv/lib/python3.10/site-packages/pandas/core/internals/blocks.py:758, in Block.astype(self, dtype, copy, errors, using_cow, squeeze)
#     755         raise ValueError("Can not squeeze with more than one column.")
#     756     values = values[0, :]  # type: ignore[call-overload]
# --> 758 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     760 new_values = maybe_coerce_values(new_values)
#     762 refs = None
#
# File ~/anaconda3/envs/ds_conda_venv/lib/python3.10/site-packages/pandas/core/dtypes/astype.py:237, in astype_array_safe(values, dtype, copy, errors)
#     234     dtype = dtype.numpy_dtype
#     236 try:
# --> 237     new_values = astype_array(values, dtype, copy=copy)
#     238 except (ValueError, TypeError):
#     239     # e.g. _astype_nansafe can fail on object-dtype of strings
#     240     #  trying to convert to float
#     241     if errors == "ignore":
#
# File ~/anaconda3/envs/ds_conda_venv/lib/python3.10/site-packages/pandas/core/dtypes/astype.py:182, in astype_array(values, dtype, copy)
#     179     values = values.astype(dtype, copy=copy)
#     181 else:
# --> 182     values = _astype_nansafe(values, dtype, copy=copy)
#     184 # in pandas we don't store numpy str dtypes, so convert to object
#     185 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File ~/anaconda3/envs/ds_conda_venv/lib/python3.10/site-packages/pandas/core/dtypes/astype.py:101, in _astype_nansafe(arr, dtype, copy, skipna)
#      96     return lib.ensure_string_array(
#      97         arr, skipna=skipna, convert_na_value=False
#      98     ).reshape(shape)
#     100 elif np.issubdtype(arr.dtype, np.floating) and dtype.kind in "iu":
# --> 101     return _astype_float_to_int_nansafe(arr, dtype, copy)
#     103 elif arr.dtype == object:
#     104     # if we have a datetime/timedelta array of objects
#     105     # then coerce to datetime64[ns] and use DatetimeArray.astype
#     107     if lib.is_np_dtype(dtype, "M"):
#
# File ~/anaconda3/envs/ds_conda_venv/lib/python3.10/site-packages/pandas/core/dtypes/astype.py:145, in _astype_float_to_int_nansafe(values, dtype, copy)
#     141 """
#     142 astype with a check preventing converting NaN to an meaningless integer value.
#     143 """
#     144 if not np.isfinite(values).all():
# --> 145     raise IntCastingNaNError(
#     146         "Cannot convert non-finite values (NA or inf) to integer"
#     147     )
#     148 if dtype.kind == "u":
#     149     # GH#45151
#     150     if not (values >= 0).all():
#
# IntCastingNaNError: Cannot convert non-finite values (NA or inf) to integer

# %%
real_estate_df['Year Built int'].value_counts()
# Out:
# Year Built int
# 2022.0    5
# 1975.0    3
# 1940.0    3
# 1959.0    2
# 1920.0    2
# 1938.0    2
# 1955.0    2
# 1899.0    2
# 1950.0    2
# 1921.0    1
# 1985.0    1
# 2009.0    1
# 1986.0    1
# 1932.0    1
# 1945.0    1
# 1928.0    1
# 1845.0    1
# 1965.0    1
# 1974.0    1
# 2008.0    1
# 1922.0    1
# 2007.0    1
# 1910.0    1
# 1970.0    1
# 1915.0    1
# Name: count, dtype: int64

# %%
real_estate_df['Year Built int'].describe()
# Out:
# count      39.000000
# mean     1956.897436
# std        40.996017
# min      1845.000000
# 25%      1930.000000
# 50%      1955.000000
# 75%      1980.000000
# max      2022.000000
# Name: Year Built int, dtype: float64

# %%
sns.boxenplot(y='Year Built int', data=real_estate_df)
# Out:
# <Axes: ylabel='Year Built int'>

# %%
real_estate_df.head()
# Out:
#                      Name    Neighbourhood        Year Built    Beds   Baths  \
# 0  3324 Junction Blvd #5X  Jackson Heights              Null   1 Bed  1 Bath
# 1       37-26 32nd St #5K          Astoria  Year Built: 2022  Studio  1 Bath
# 2       37-26 32nd St #3G          Astoria  Year Built: 2022   1 Bed  1 Bath
# 3       37-26 32nd St #6L          Astoria  Year Built: 2022  Studio  1 Bath
# 4       37-26 32nd St #3H          Astoria  Year Built: 2022   1 Bed  1 Bath
#
#        Area Price(per sqft)           A/C              Address Apartment  \
# 0  800 sqft            $356  Cooling only  3324 Junction Blvd         5X
# 1  441 sqft          $1,406  Cooling only       37-26 32nd St         5K
# 2  579 sqft          $1,261  Cooling only       37-26 32nd St         3G
# 3  429 sqft          $1,329  Cooling only       37-26 32nd St         6L
# 4  632 sqft          $1,100            No       37-26 32nd St         3H
#
#          City_short  postal_code state  Price_  Year Built int
# 0   Jackson Heights        11372    NY  285000             NaN
# 1  Long Island City        11101    NY  620000          2022.0
# 2  Long Island City        11101    NY  730000          2022.0
# 3  Long Island City        11101    NY  570000          2022.0
# 4  Long Island City        11101    NY  695000          2022.0

# %%
real_estate_df['Beds'].value_counts()
# Out:
# Beds
# 2 Beds    14
# 1 Bed     11
# Studio     6
# 5 Beds     3
# 4 Beds     3
# 3 Beds     2
# 6 Beds     1
# 7 Beds     1
# Name: count, dtype: int64

# %%
real_estate_df['Beds'] == 'Studio'
# Out:
# 0     False
# 1      True
# 2     False
# 3      True
# 4     False
# 5     False
# 6     False
# 7     False
# 8      True
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14     True
# 15    False
# 16    False
# 17    False
# 18    False
# 19     True
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27     True
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# Name: Beds, dtype: bool

# %%
real_estate_df.loc[real_estate_df['Beds'] == 'Studio', 'Studio'] = True

# %%
real_estate_df.loc[:,'Studio'].fillna(False, inplace=True)
# Out:
# /var/folders/pl/dfcs60nn16qdw7bltcc09p3h0000gn/T/ipykernel_7342/1110933445.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   real_estate_df.loc[:,'Studio'].fillna(False, inplace=True)
# /var/folders/pl/dfcs60nn16qdw7bltcc09p3h0000gn/T/ipykernel_7342/1110933445.py:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   real_estate_df.loc[:,'Studio'].fillna(False, inplace=True)

# %%
real_estate_df['Bed_rooms'] = 1

# %%
real_estate_df.loc[real_estate_df['Studio'] == False, 'Beds'].head()
# Out:
# 0     1 Bed
# 2     1 Bed
# 4     1 Bed
# 5    2 Beds
# 6     1 Bed
# Name: Beds, dtype: object

# %%
real_estate_df.loc[real_estate_df['Studio'] == False, 'Bed_rooms'] = real_estate_df.loc[real_estate_df['Studio'] == False, 'Beds'].str.split(' ').str.get(0).astype(int)

# %%
real_estate_df.head()
# Out:
#                      Name    Neighbourhood        Year Built    Beds   Baths  \
# 0  3324 Junction Blvd #5X  Jackson Heights              Null   1 Bed  1 Bath
# 1       37-26 32nd St #5K          Astoria  Year Built: 2022  Studio  1 Bath
# 2       37-26 32nd St #3G          Astoria  Year Built: 2022   1 Bed  1 Bath
# 3       37-26 32nd St #6L          Astoria  Year Built: 2022  Studio  1 Bath
# 4       37-26 32nd St #3H          Astoria  Year Built: 2022   1 Bed  1 Bath
#
#        Area Price(per sqft)           A/C              Address Apartment  \
# 0  800 sqft            $356  Cooling only  3324 Junction Blvd         5X
# 1  441 sqft          $1,406  Cooling only       37-26 32nd St         5K
# 2  579 sqft          $1,261  Cooling only       37-26 32nd St         3G
# 3  429 sqft          $1,329  Cooling only       37-26 32nd St         6L
# 4  632 sqft          $1,100            No       37-26 32nd St         3H
#
#          City_short  postal_code state  Price_  Year Built int  Studio  \
# 0   Jackson Heights        11372    NY  285000             NaN   False
# 1  Long Island City        11101    NY  620000          2022.0    True
# 2  Long Island City        11101    NY  730000          2022.0   False
# 3  Long Island City        11101    NY  570000          2022.0    True
# 4  Long Island City        11101    NY  695000          2022.0   False
#
#    Bed_rooms
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1

# %%
real_estate_df['Baths'].value_counts()
# Out:
# Baths
# 1 Bath     17
# 2 Baths    17
# 4 Baths     3
# 3 Baths     2
# 5 Baths     1
# 6 Baths     1
# Name: count, dtype: int64

# %%
real_estate_df['Baths'] = real_estate_df['Baths'].str.split(' ').str.get(0).astype(int)

# %%
real_estate_df.head()
# Out:
#                      Name    Neighbourhood        Year Built    Beds  Baths  \
# 0  3324 Junction Blvd #5X  Jackson Heights              Null   1 Bed      1
# 1       37-26 32nd St #5K          Astoria  Year Built: 2022  Studio      1
# 2       37-26 32nd St #3G          Astoria  Year Built: 2022   1 Bed      1
# 3       37-26 32nd St #6L          Astoria  Year Built: 2022  Studio      1
# 4       37-26 32nd St #3H          Astoria  Year Built: 2022   1 Bed      1
#
#        Area Price(per sqft)           A/C              Address Apartment  \
# 0  800 sqft            $356  Cooling only  3324 Junction Blvd         5X
# 1  441 sqft          $1,406  Cooling only       37-26 32nd St         5K
# 2  579 sqft          $1,261  Cooling only       37-26 32nd St         3G
# 3  429 sqft          $1,329  Cooling only       37-26 32nd St         6L
# 4  632 sqft          $1,100            No       37-26 32nd St         3H
#
#          City_short  postal_code state  Price_  Year Built int  Studio  \
# 0   Jackson Heights        11372    NY  285000             NaN   False
# 1  Long Island City        11101    NY  620000          2022.0    True
# 2  Long Island City        11101    NY  730000          2022.0   False
# 3  Long Island City        11101    NY  570000          2022.0    True
# 4  Long Island City        11101    NY  695000          2022.0   False
#
#    Bed_rooms
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1

# %%
real_estate_df['Area'].value_counts()
# Out:
# Area
# Null                            14
# 800 sqft                         2
# 1,100 sqft                       2
# 528 sqft                         1
# 916 sqft                         1
# 1,180 sqft                       1
# 650 sqft                         1
# 1,140 sqft                       1
# 1,275 sqft                       1
# 764 sqft                         1
# 1,899 sqft                       1
# 1,185 sqft                       1
# 3,192 sqft                       1
# 880 sqft                         1
# 441 sqft                         1
# 100,964 sqft (on 0.46 acres)     1
# 2,400 sqft                       1
# 513 sqft                         1
# 842 sqft                         1
# 1,816 sqft                       1
# 6,300 sqft                       1
# 850 sqft                         1
# 632 sqft                         1
# 429 sqft                         1
# 579 sqft                         1
# 934 sqft                         1
# Name: count, dtype: int64

# %%
real_estate_df['Area'] = real_estate_df['Area'].str.split(' sqft').str.get(0).str.replace(',', '').replace('Null', np.nan).astype(float)

# %%
real_estate_df['Area']
# Out:
# 0        800.0
# 1        441.0
# 2        579.0
# 3        429.0
# 4        632.0
# 5          NaN
# 6        850.0
# 7          NaN
# 8       6300.0
# 9       1816.0
# 10         NaN
# 11         NaN
# 12       842.0
# 13         NaN
# 14       513.0
# 15      2400.0
# 16    100964.0
# 17       880.0
# 18         NaN
# 19       528.0
# 20         NaN
# 21      3192.0
# 22      1185.0
# 23         NaN
# 24      1100.0
# 25      1899.0
# 26         NaN
# 27         NaN
# 28         NaN
# 29       800.0
# 30       764.0
# 31         NaN
# 32      1275.0
# 33      1140.0
# 34       650.0
# 35      1180.0
# 36      1100.0
# 37         NaN
# 38       916.0
# 39       934.0
# 40         NaN
# Name: Area, dtype: float64

# %%
real_estate_df.head()
# Out:
#                      Name    Neighbourhood        Year Built    Beds  Baths  \
# 0  3324 Junction Blvd #5X  Jackson Heights              Null   1 Bed      1
# 1       37-26 32nd St #5K          Astoria  Year Built: 2022  Studio      1
# 2       37-26 32nd St #3G          Astoria  Year Built: 2022   1 Bed      1
# 3       37-26 32nd St #6L          Astoria  Year Built: 2022  Studio      1
# 4       37-26 32nd St #3H          Astoria  Year Built: 2022   1 Bed      1
#
#     Area Price(per sqft)           A/C              Address Apartment  \
# 0  800.0            $356  Cooling only  3324 Junction Blvd         5X
# 1  441.0          $1,406  Cooling only       37-26 32nd St         5K
# 2  579.0          $1,261  Cooling only       37-26 32nd St         3G
# 3  429.0          $1,329  Cooling only       37-26 32nd St         6L
# 4  632.0          $1,100            No       37-26 32nd St         3H
#
#          City_short  postal_code state  Price_  Year Built int  Studio  \
# 0   Jackson Heights        11372    NY  285000             NaN   False
# 1  Long Island City        11101    NY  620000          2022.0    True
# 2  Long Island City        11101    NY  730000          2022.0   False
# 3  Long Island City        11101    NY  570000          2022.0    True
# 4  Long Island City        11101    NY  695000          2022.0   False
#
#    Bed_rooms
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1

# %%
real_estate_df['price_per_sqft'] = real_estate_df['Price_'] / real_estate_df['Area']

# %%
real_estate_df[['Price(per sqft)', 'price_per_sqft']].drop_duplicates()
# Out:
#    Price(per sqft)  price_per_sqft
# 0             $356      356.250000
# 1           $1,406     1405.895692
# 2           $1,261     1260.794473
# 3           $1,329     1328.671329
# 4           $1,100     1099.683544
# 5          No Info             NaN
# 6             $278      277.641176
# 8             $206      206.349206
# 9             $509      509.361233
# 12            $746      745.843230
# 14          $1,467     1466.666667
# 15            $915      914.583333
# 16             $12       12.375698
# 17            $976      976.136364
# 19          $1,203     1202.651515
# 21          $1,410     1409.774436
# 22          $1,177     1177.215190
# 24            $254      254.454545
# 25            $573      573.459716
# 29            $224      223.750000
# 30            $720      719.895288
# 32          $1,255     1254.901961
# 33            $740      739.912281
# 34          $1,308     1307.692308
# 35            $381      381.355932
# 36            $772      771.818182
# 38            $431      431.222707
# 39            $438      437.781585

# %%
real_estate_df['price_per_sqft'] = real_estate_df['price_per_sqft'].apply(lambda p: np.round(p, 0))

# %%
plt.plot(real_estate_df['Price_'], real_estate_df['Area'], 'o')
plt.xlabel('Price')
plt.ylabel('Area')
# Out:
# Text(0, 0.5, 'Area')

# %%
real_estate_df[['Price_','Area']]
# Out:
#      Price_      Area
# 0    285000     800.0
# 1    620000     441.0
# 2    730000     579.0
# 3    570000     429.0
# 4    695000     632.0
# 5   1200000       NaN
# 6    235995     850.0
# 7    388000       NaN
# 8   1300000    6300.0
# 9    925000    1816.0
# 10   299000       NaN
# 11   619000       NaN
# 12   628000     842.0
# 13   285000       NaN
# 14   752400     513.0
# 15  2195000    2400.0
# 16  1249500  100964.0
# 17   859000     880.0
# 18   775000       NaN
# 19   635000     528.0
# 20   569000       NaN
# 21  4500000    3192.0
# 22  1395000    1185.0
# 23   595000       NaN
# 24   279900    1100.0
# 25  1089000    1899.0
# 26  1825000       NaN
# 27   320000       NaN
# 28   969000       NaN
# 29   179000     800.0
# 30   550000     764.0
# 31   575000       NaN
# 32  1600000    1275.0
# 33   843500    1140.0
# 34   850000     650.0
# 35   450000    1180.0
# 36   849000    1100.0
# 37   999900       NaN
# 38   395000     916.0
# 39   408888     934.0
# 40  1825000       NaN

# %%
price_area = real_estate_df[['Price_','Area']].dropna()

# %%
price_area['Area'].sort_values().values
# Out:
# array([   429.,    441.,    513.,    528.,    579.,    632.,    650.,
#           764.,    800.,    800.,    842.,    850.,    880.,    916.,
#           934.,   1100.,   1100.,   1140.,   1180.,   1185.,   1275.,
#          1816.,   1899.,   2400.,   3192.,   6300., 100964.])

# %%
plt.plot(price_area['Price_'].sort_values().values[0:-1], price_area['Area'].sort_values().values[0:-1], 'o')
plt.xlabel('Price')
plt.ylabel('Area')
# Out:
# Text(0, 0.5, 'Area')

# %%
real_estate_df.head()
# Out:
#                      Name    Neighbourhood        Year Built    Beds  Baths  \
# 0  3324 Junction Blvd #5X  Jackson Heights              Null   1 Bed      1
# 1       37-26 32nd St #5K          Astoria  Year Built: 2022  Studio      1
# 2       37-26 32nd St #3G          Astoria  Year Built: 2022   1 Bed      1
# 3       37-26 32nd St #6L          Astoria  Year Built: 2022  Studio      1
# 4       37-26 32nd St #3H          Astoria  Year Built: 2022   1 Bed      1
#
#     Area Price(per sqft)           A/C              Address Apartment  \
# 0  800.0            $356  Cooling only  3324 Junction Blvd         5X
# 1  441.0          $1,406  Cooling only       37-26 32nd St         5K
# 2  579.0          $1,261  Cooling only       37-26 32nd St         3G
# 3  429.0          $1,329  Cooling only       37-26 32nd St         6L
# 4  632.0          $1,100            No       37-26 32nd St         3H
#
#          City_short  postal_code state  Price_  Year Built int  Studio  \
# 0   Jackson Heights        11372    NY  285000             NaN   False
# 1  Long Island City        11101    NY  620000          2022.0    True
# 2  Long Island City        11101    NY  730000          2022.0   False
# 3  Long Island City        11101    NY  570000          2022.0    True
# 4  Long Island City        11101    NY  695000          2022.0   False
#
#    Bed_rooms  price_per_sqft
# 0          1           356.0
# 1          1          1406.0
# 2          1          1261.0
# 3          1          1329.0
# 4          1          1100.0

# %%
real_estate_df.drop(columns='Price(per sqft)', inplace=True)

# %%
real_estate_df['A/C'].value_counts()
# Out:
# A/C
# No                   15
# Heating & Cooling    11
# Cooling only          9
# Heating only          6
# Name: count, dtype: int64

# %%
real_estate_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41 entries, 0 to 40
# Data columns (total 17 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Name            41 non-null     object
#  1   Neighbourhood   41 non-null     object
#  2   Year Built      41 non-null     object
#  3   Beds            41 non-null     object
#  4   Baths           41 non-null     int64
#  5   Area            27 non-null     float64
#  6   A/C             41 non-null     object
#  7   Address         41 non-null     object
#  8   Apartment       26 non-null     object
#  9   City_short      41 non-null     object
#  10  postal_code     41 non-null     int64
#  11  state           41 non-null     object
#  12  Price_          41 non-null     int64
#  13  Year Built int  39 non-null     float64
#  14  Studio          41 non-null     bool
#  15  Bed_rooms       41 non-null     int64
#  16  price_per_sqft  27 non-null     float64
# dtypes: bool(1), float64(3), int64(4), object(9)
# memory usage: 5.3+ KB

# %% [markdown]
# # Fuzzy Logic/ Geolocation

# %%
# Load Tax Data
mapPluto_df = pd.read_csv('https://raw.githubusercontent.com/Shai2u/gis_ml_workshop_winter_2024_2025/refs/heads/Ex_2/Ex_2/mapPluto_sample.csv', index_col=0)

# %%
mapPluto_df.head()
# Out:
#   Borough                  Address   Latitude  Longitude
# 0      MN         377 RECTOR PLACE  40.709851 -74.017891
# 1      MN  54 STANTON ST EXTENSION  40.704283 -74.010120
# 2      MN                 62 AVE C  40.722504 -73.979678
# 3      MN     661 AMSTERDAM AVENUE  40.791681 -73.971690
# 4      BX     2339 MATTHEWS AVENUE  40.860773 -73.863017

# %%
print(f"MapPluto: {len(mapPluto_df)}, RealEstate: {len(real_estate_df)}")
# Out:
# MapPluto: 7534, RealEstate: 41

# %%
mapPluto_df['Borough'].value_counts()
# Out:
# Borough
# QN    1513
# BK    1509
# MN    1504
# BX    1504
# SI    1504
# Name: count, dtype: int64

# %%
mapPluto_df.head()
# Out:
#   Borough                  Address   Latitude  Longitude
# 0      MN         377 RECTOR PLACE  40.709851 -74.017891
# 1      MN  54 STANTON ST EXTENSION  40.704283 -74.010120
# 2      MN                 62 AVE C  40.722504 -73.979678
# 3      MN     661 AMSTERDAM AVENUE  40.791681 -73.971690
# 4      BX     2339 MATTHEWS AVENUE  40.860773 -73.863017

# %%
real_estate_df.head()
# Out:
#                      Name    Neighbourhood        Year Built    Beds  Baths  \
# 0  3324 Junction Blvd #5X  Jackson Heights              Null   1 Bed      1
# 1       37-26 32nd St #5K          Astoria  Year Built: 2022  Studio      1
# 2       37-26 32nd St #3G          Astoria  Year Built: 2022   1 Bed      1
# 3       37-26 32nd St #6L          Astoria  Year Built: 2022  Studio      1
# 4       37-26 32nd St #3H          Astoria  Year Built: 2022   1 Bed      1
#
#     Area           A/C              Address Apartment        City_short  \
# 0  800.0  Cooling only  3324 Junction Blvd         5X   Jackson Heights
# 1  441.0  Cooling only       37-26 32nd St         5K  Long Island City
# 2  579.0  Cooling only       37-26 32nd St         3G  Long Island City
# 3  429.0  Cooling only       37-26 32nd St         6L  Long Island City
# 4  632.0            No       37-26 32nd St         3H  Long Island City
#
#    postal_code state  Price_  Year Built int  Studio  Bed_rooms  \
# 0        11372    NY  285000             NaN   False          1
# 1        11101    NY  620000          2022.0    True          1
# 2        11101    NY  730000          2022.0   False          1
# 3        11101    NY  570000          2022.0    True          1
# 4        11101    NY  695000          2022.0   False          1
#
#    price_per_sqft
# 0           356.0
# 1          1406.0
# 2          1261.0
# 3          1329.0
# 4          1100.0

# %%
mapPluto_df['Address'].isin(real_estate_df['Address'].unique()).sum()
# Out:
# 0

# %%
match, score = process.extractOne('3324 Junction Blvd', mapPluto_df['Address'].unique())

# %%
print(f"match: {match}, score: {score}")
# Out:
# match: 33-43 JUNCTION BLVD, score: 92

# %%
def get_best_match(addr_df, choices):
    match, score = process.extractOne(addr_df, choices)
    return match if score > 80 else np.nan

# %%
addresses = mapPluto_df['Address'].unique().tolist()

# %%
len(addresses)
# Out:
# 7518

# %%
print(addresses[0:10])
# Out:
# ['377 RECTOR PLACE', '54 STANTON ST EXTENSION', '62 AVE C', '661 AMSTERDAM AVENUE', '2339 MATTHEWS AVENUE', '3112 MICKLE AVENUE', '2973 INDEPENDENCE AVENUE', '3656 JOHNSON AVENUE', '140 LAWRENCE STREET', '43 JORALEMON STREET']

# %%
mapPluto_df['Address'][0:20].apply(lambda addr: get_best_match(addr, addresses))
# Out:
# 0             377 RECTOR PLACE
# 1      54 STANTON ST EXTENSION
# 2                     62 AVE C
# 3         661 AMSTERDAM AVENUE
# 4         2339 MATTHEWS AVENUE
# 5           3112 MICKLE AVENUE
# 6     2973 INDEPENDENCE AVENUE
# 7          3656 JOHNSON AVENUE
# 8          140 LAWRENCE STREET
# 9          43 JORALEMON STREET
# 10          580 CARROLL STREET
# 11       1285A ST MARKS AVENUE
# 12           433 MONROE STREET
# 13          195 CLASSON AVENUE
# 14              1247 86 STREET
# 15              51-24 2 STREET
# 16      45-40 VERNON BOULEVARD
# 17      46-42 VERNON BOULEVARD
# 18              5-43 48 AVENUE
# 19        10-37 JACKSON AVENUE
# Name: Address, dtype: object

# %% [markdown]
# ## 😣 This takes too much time! ⌛️
# lets try to reduce the process of time and make the model run faster

# %%
mapPluto_df.head()
# Out:
#   Borough                  Address   Latitude  Longitude
# 0      MN         377 RECTOR PLACE  40.709851 -74.017891
# 1      MN  54 STANTON ST EXTENSION  40.704283 -74.010120
# 2      MN                 62 AVE C  40.722504 -73.979678
# 3      MN     661 AMSTERDAM AVENUE  40.791681 -73.971690
# 4      BX     2339 MATTHEWS AVENUE  40.860773 -73.863017

# %%
print(real_estate_df['City_short'].unique(), mapPluto_df['Borough'].unique())
# Out:
# ['Jackson Heights' 'Long Island City' 'New York' 'Bronx' 'Oakland Gardens'
#  'Staten Island' 'Brooklyn' 'Forest Hills' 'Richmond Hill' 'Flushing'
#  'Rego Park' 'Hollis' 'Jamaica'] ['MN' 'BX' 'BK' 'QN' 'SI']

# %%
city_to_borough = {'Jackson Heights' :'QN',
'Long Island City': 'QN',
'New York': 'MN',
'Bronx': 'BX',
'Oakland Gardens': 'QN',
'Staten Island': 'SI',
'Brooklyn' : 'BK',
'Forest Hills': 'QN',
'Richmond Hill': 'QN',
'Flushing':'QN',
'Rego Park':'QN',
'Hollis':'QN', 
'Jamaica':'QN'}

# %%
real_estate_df['Borough'] = real_estate_df['City_short'].apply(city_to_borough.get)

# %%
real_estate_df.head(2)
# Out:
#                      Name    Neighbourhood        Year Built    Beds  Baths  \
# 0  3324 Junction Blvd #5X  Jackson Heights              Null   1 Bed      1
# 1       37-26 32nd St #5K          Astoria  Year Built: 2022  Studio      1
#
#     Area           A/C              Address Apartment        City_short  \
# 0  800.0  Cooling only  3324 Junction Blvd         5X   Jackson Heights
# 1  441.0  Cooling only       37-26 32nd St         5K  Long Island City
#
#    postal_code state  Price_  Year Built int  Studio  Bed_rooms  \
# 0        11372    NY  285000             NaN   False          1
# 1        11101    NY  620000          2022.0    True          1
#
#    price_per_sqft Borough
# 0           356.0      QN
# 1          1406.0      QN

# %%
def get_best_match(addr_df, choices):
    borough = addr_df['Borough']
    addr = addr_df['Address']
    choices_subset = choices[choices['Borough']== borough]['Address'].tolist()
    match, score = process.extractOne(addr, choices_subset)
    return match if score > 80 else np.nan

tqdm.pandas()
df_03 = real_estate_df.iloc[0:].copy()

# %%
real_estate_df['Matched Address'] = real_estate_df.progress_apply(
    lambda p: get_best_match(p, mapPluto_df), axis=1)
# Out:
# 100%|██████████| 41/41 [00:01<00:00, 40.98it/s]

# %%
real_estate_df.head()
# Out:
#                      Name    Neighbourhood        Year Built    Beds  Baths  \
# 0  3324 Junction Blvd #5X  Jackson Heights              Null   1 Bed      1
# 1       37-26 32nd St #5K          Astoria  Year Built: 2022  Studio      1
# 2       37-26 32nd St #3G          Astoria  Year Built: 2022   1 Bed      1
# 3       37-26 32nd St #6L          Astoria  Year Built: 2022  Studio      1
# 4       37-26 32nd St #3H          Astoria  Year Built: 2022   1 Bed      1
#
#     Area           A/C              Address Apartment        City_short  \
# 0  800.0  Cooling only  3324 Junction Blvd         5X   Jackson Heights
# 1  441.0  Cooling only       37-26 32nd St         5K  Long Island City
# 2  579.0  Cooling only       37-26 32nd St         3G  Long Island City
# 3  429.0  Cooling only       37-26 32nd St         6L  Long Island City
# 4  632.0            No       37-26 32nd St         3H  Long Island City
#
#    postal_code state  Price_  Year Built int  Studio  Bed_rooms  \
# 0        11372    NY  285000             NaN   False          1
# 1        11101    NY  620000          2022.0    True          1
# 2        11101    NY  730000          2022.0   False          1
# 3        11101    NY  570000          2022.0    True          1
# 4        11101    NY  695000          2022.0   False          1
#
#    price_per_sqft Borough       Matched Address
# 0           356.0      QN   33-43 JUNCTION BLVD
# 1          1406.0      QN  10-37 JACKSON AVENUE
# 2          1261.0      QN  10-37 JACKSON AVENUE
# 3          1329.0      QN  10-37 JACKSON AVENUE
# 4          1100.0      QN  10-37 JACKSON AVENUE

# %%
real_estate_lat_long = real_estate_df.merge(mapPluto_df.drop(columns=['Borough']), left_on='Matched Address', right_on='Address', how='left', suffixes=['','_'])

# %%
real_estate_lat_long.head()
# Out:
#                      Name    Neighbourhood        Year Built    Beds  Baths  \
# 0  3324 Junction Blvd #5X  Jackson Heights              Null   1 Bed      1
# 1       37-26 32nd St #5K          Astoria  Year Built: 2022  Studio      1
# 2       37-26 32nd St #3G          Astoria  Year Built: 2022   1 Bed      1
# 3       37-26 32nd St #6L          Astoria  Year Built: 2022  Studio      1
# 4       37-26 32nd St #3H          Astoria  Year Built: 2022   1 Bed      1
#
#     Area           A/C              Address Apartment        City_short  ...  \
# 0  800.0  Cooling only  3324 Junction Blvd         5X   Jackson Heights  ...
# 1  441.0  Cooling only       37-26 32nd St         5K  Long Island City  ...
# 2  579.0  Cooling only       37-26 32nd St         3G  Long Island City  ...
# 3  429.0  Cooling only       37-26 32nd St         6L  Long Island City  ...
# 4  632.0            No       37-26 32nd St         3H  Long Island City  ...
#
#    Price_ Year Built int  Studio  Bed_rooms  price_per_sqft  Borough  \
# 0  285000            NaN   False          1           356.0       QN
# 1  620000         2022.0    True          1          1406.0       QN
# 2  730000         2022.0   False          1          1261.0       QN
# 3  570000         2022.0    True          1          1329.0       QN
# 4  695000         2022.0   False          1          1100.0       QN
#
#         Matched Address              Address_   Latitude  Longitude
# 0   33-43 JUNCTION BLVD   33-43 JUNCTION BLVD  40.755650 -73.872658
# 1  10-37 JACKSON AVENUE  10-37 JACKSON AVENUE  40.742443 -73.953256
# 2  10-37 JACKSON AVENUE  10-37 JACKSON AVENUE  40.742443 -73.953256
# 3  10-37 JACKSON AVENUE  10-37 JACKSON AVENUE  40.742443 -73.953256
# 4  10-37 JACKSON AVENUE  10-37 JACKSON AVENUE  40.742443 -73.953256
#
# [5 rows x 22 columns]

# %% [markdown]
# # Plot Geographicly

# %%
real_estate_gdf = gpd.GeoDataFrame(real_estate_lat_long, crs=4326,  geometry=gpd.points_from_xy(real_estate_lat_long['Longitude'], real_estate_lat_long['Latitude']))

# %%
real_estate_gdf.explore(
    column='Price_',
    cmap='RdYlGn',
    legend=True,
    tiles="CartoDB positron"
)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7a4c07a5802e293c27af99b4e991aa2b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7a4c07a5802e293c27af99b4e991aa2b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7a4c07a5802e293c27af99b4e991aa2b = L.map(
#                 &quot;map_7a4c07a5802e293c27af99b4e991aa2b&quot;,
#                 {
#                     center: [40.733415949999994, -73.96195705],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_7a4c07a5802e293c27af99b4e991aa2b);
#
#
#
#
#
#             var tile_layer_3041ce7dfd601faa22b707f7a0d360f2 = L.tileLayer(
#                 &quot;https://a.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_3041ce7dfd601faa22b707f7a0d360f2.addTo(map_7a4c07a5802e293c27af99b4e991aa2b);
#
#
#             map_7a4c07a5802e293c27af99b4e991aa2b.fitBounds(
#                 [[40.5786599, -74.1630432], [40.888172, -73.7608709]],
#                 {}
#             );
#
#
#         function geo_json_9ac04263913ce8af5c8a585cf23eb575_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;: case &quot;13&quot;:
#                     return {&quot;color&quot;: &quot;#b10b26&quot;, &quot;fillColor&quot;: &quot;#b10b26&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;1&quot;: case &quot;11&quot;: case &quot;12&quot;:
#                     return {&quot;color&quot;: &quot;#d83128&quot;, &quot;fillColor&quot;: &quot;#d83128&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;2&quot;:
#                     return {&quot;color&quot;: &quot;#de402e&quot;, &quot;fillColor&quot;: &quot;#de402e&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;3&quot;: case &quot;20&quot;: case &quot;31&quot;:
#                     return {&quot;color&quot;: &quot;#d22b27&quot;, &quot;fillColor&quot;: &quot;#d22b27&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;4&quot;:
#                     return {&quot;color&quot;: &quot;#dc3b2c&quot;, &quot;fillColor&quot;: &quot;#dc3b2c&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;5&quot;:
#                     return {&quot;color&quot;: &quot;#f7844e&quot;, &quot;fillColor&quot;: &quot;#f7844e&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;6&quot;:
#                     return {&quot;color&quot;: &quot;#ab0626&quot;, &quot;fillColor&quot;: &quot;#ab0626&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;7&quot;: case &quot;38&quot;:
#                     return {&quot;color&quot;: &quot;#bd1726&quot;, &quot;fillColor&quot;: &quot;#bd1726&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;8&quot;:
#                     return {&quot;color&quot;: &quot;#f99355&quot;, &quot;fillColor&quot;: &quot;#f99355&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;10&quot;:
#                     return {&quot;color&quot;: &quot;#b30d26&quot;, &quot;fillColor&quot;: &quot;#b30d26&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;14&quot;:
#                     return {&quot;color&quot;: &quot;#e0422f&quot;, &quot;fillColor&quot;: &quot;#e0422f&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;15&quot;:
#                     return {&quot;color&quot;: &quot;#fff5ae&quot;, &quot;fillColor&quot;: &quot;#fff5ae&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;16&quot;:
#                     return {&quot;color&quot;: &quot;#f88c51&quot;, &quot;fillColor&quot;: &quot;#f88c51&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;17&quot;:
#                     return {&quot;color&quot;: &quot;#e75337&quot;, &quot;fillColor&quot;: &quot;#e75337&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;18&quot;:
#                     return {&q
